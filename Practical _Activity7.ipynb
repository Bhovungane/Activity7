# %%
import seaborn as sns
import matplotlib.pyplot as plot
import pandas as pd

# %% [markdown]
# Read csv file

# %%
df=pd.read_csv("C:/Users/27797/Downloads/dataset - 2020-09-24.csv")

# %% [markdown]
# display columns

# %%
print(df.columns)
# Out:
# Index(['Name', 'Jersey Number', 'Club', 'Position', 'Nationality', 'Age',
#        'Appearances', 'Wins', 'Losses', 'Goals', 'Goals per match',
#        'Headed goals', 'Goals with right foot', 'Goals with left foot',
#        'Penalties scored', 'Freekicks scored', 'Shots', 'Shots on target',
#        'Shooting accuracy %', 'Hit woodwork', 'Big chances missed',
#        'Clean sheets', 'Goals conceded', 'Tackles', 'Tackle success %',
#        'Last man tackles', 'Blocked shots', 'Interceptions', 'Clearances',
#        'Headed Clearance', 'Clearances off line', 'Recoveries', 'Duels won',
#        'Duels lost', 'Successful 50/50s', 'Aerial battles won',
#        'Aerial battles lost', 'Own goals', 'Errors leading to goal', 'Assists',
#        'Passes', 'Passes per match', 'Big chances created', 'Crosses',
#        'Cross accuracy %', 'Through balls', 'Accurate long balls', 'Saves',
#        'Penalties saved', 'Punches', 'High Claims', 'Catches',
# ...

# %% [markdown]
# This is line plot graph

# %%
sns.set_theme()

# %%
sns.set_style("whitegrid")

# %%
sns.lineplot(x='Penalties scored',y='Freekicks scored',data=df)
plot.show()

# %% [markdown]
# Second lineplot graph but different columns

# %%
sns.lineplot(x='Shots on target', y='Goals per match', data=df)
plot.show()

# %% [markdown]
# This is distribution plot graph for lineplot graph number 1

# %%
sns.displot(df['Penalties scored'])
plot.show()

# %% [markdown]
# This distribution lineplot graph for another column

# %%
sns.displot(df['Freekicks scored'])
plot.show()

# %% [markdown]
# This is a kde lineplot graph for graph number 2

# %%
sns.kdeplot(df['Shots on target'],fill=True)
plot.show()

# %% [markdown]
# This is kde lineplot graph for second column

# %%
sns.kdeplot(df['Goals per match'],fill=True)
plot.show()

# %% [markdown]
# This is rug plot graph

# %%
sns.rugplot(df['Goals per match'])
plot.show()

# %% [markdown]
# another rug plot graph for another column

# %%
sns.rugplot(df['Shots on target'])
plot.show()

# %% [markdown]
# This is box plot for number 1

# %%
sns.boxplot(x='Penalties scored',y='Freekicks scored',data=df)
plot.show()

# %% [markdown]
# This is boxplot for line plot number 2

# %%
sns.boxplot(x='Goals per match',y='Shots on target',data=df)
plot.show()

# %% [markdown]
# This is violinplot for lineplot graph number 1

# %%
sns.violinplot(x='Goals per match',y='Shots on target',data=df)
plot.show()

# %% [markdown]
# This is violin lineplot graph for number 1

# %%
sns.violinplot(x='Penalties scored',y='Freekicks scored',data=df)
plot.show()

# %% [markdown]
# This is Swarmplot graph for line plot number 1

# %%
sns.swarmplot(x='Penalties scored',y='Freekicks scored',data=df)
plot.show()
# Out:
# C:\Users\27797\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 95.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\27797\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\27797\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 45.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# This is swarmplot graph for lineplot graph number 2

# %%
sns.swarmplot(x='Goals per match',y='Shots on target',data=df)
plot.show()
# Out:
# C:\Users\27797\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\27797\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 72.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\27797\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 70.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\27797\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 54.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# This is pairplot lineplot graph for number 1

# %%
sns.pairplot(df,hue='Freekicks scored')
plot.show()

# %% [markdown]
# This is jointplot for lineplot graph number 1

# %%
sns.jointplot(x='Goals per match',y='Shots on target',data=df,kind='scatter')
plot.show()
